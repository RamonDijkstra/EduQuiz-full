# %%
import openai
import os
import json
from transformers import GPT2Tokenizer

# %%
# Change these variables to perform completion for you task

api_key_path = '<PATH_TO_YOUR_API_KEY_TXT_FILE>'
test_path = os.path.abspath(os.getcwd()).split('gpt3_completion_scripts')[0] + 'processed_data/gpt3/completion_4/processed_test.json'
FINE_TUNED_FQ_MODEL = '<NAME_FINE_TUNED_GPT3_COMPLETION_4>'
outfile = os.path.abspath(os.getcwd()).split('gpt3_completion_scripts')[0] + 'generated_data_gpt3/experiment_4/generated_distractors.json'

# %%
with open(api_key_path) as f:
    openai.api_key = f.read()

# %%
# Open train/val datasets

test_data = []

for line in open(test_path):
    test_data.append((json.loads(line)))

# %%
GPT2tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# %%
# The index is also printed below. It can occur that the OpenAI server is overload.
# To overcome the issue of losing all information manually change the for i in range(len(test_data)) line
# For example: the server gets overloaded on number 150
# Change the code to for i in range(151, len(test_data)), comment out generated = {} and continue the process

# %%
generated = {}

for i in range(len(test_data)):
    prompt = test_data[i]['prompt']
    
    if len(GPT2tokenizer(prompt)['input_ids']) + 200 < 2048:
        output = openai.Completion.create(
                    model=FINE_TUNED_FQ_MODEL,
                    max_tokens = 200,
                    temperature = 0,
                    frequency_penalty = 0,
                    presence_penalty =  0,
                    stop = '\n###',
                    prompt = prompt)
        print(i, output['choices'][0]['text'])
        generated[i+1] = output['choices'][0]['text']
# Out:
# 0  False answer: Because her mother died when she was five.
# False answer: Because her family didn't love her.
# False answer: Because she wanted a football instead.
# 1  False answer: He delivered the gifts bought by Alice's mother.
# False answer: He played the part of Santa Claus in Alice's area.
# False answer: He delivered the gifts bought by Katie.
# 2  False answer: She thought her mother didn't like her.
# False answer: She was sure her mother didn't remember the date.
# False answer: She thought her mother didn't need a gift.
# 3  False answer: His hands and arms.
# False answer: His head and neck.
# False answer: His back and waist.
# 4  False answer: Jerry Springer is a famous person.
# False answer: Jerry Springer is clean and tidy.
# False answer: Jerry Springer can make a speech about the entire idea of the show.
# 5  False answer: Because he enjoyed the violence of boxing.
# False answer: Because he was curious about how one moved one's body to protect oneself.
# False answer: Because he was good at boxing.
# 6  False answer: He could not see the text clearly.
# False answer: He lost his glasses in the crowd.
# False answer: He had to borrow glasses from his wife.
# 7  False answer: His friend
# False answer: His training
# False answer: His experience
# 8  False answer: Never too late to learn
# False answer: Anger is the biggest enemy
# False answer: A good reputation is more important than wealth
# 9  False answer: Tank Loft, Chongqing.
# False answer: M50, Shanghai.
# False answer: 798 Art Zone, Beijing.
# 10  False answer: In the newspapers.
# False answer: In restaurants.
# False answer: In shops.
# 11  False answer: Schools where parents can send their children
# False answer: Equipment for all grades
# False answer: Special corner offering deeper discounts
# 12  False answer: Angry.
# False answer: Nervous.
# False answer: Hopeless.
# 13  False answer: To make Native American music popular.
# False answer: To protect the Catawba tribe.
# False answer: To spread Native American culture.
# 14  False answer: Good pay.
# False answer: Pupils from rich families.
# False answer: Good school.
# 15  False answer: Have a good knowledge of science.
# False answer: Have experience in teaching in the UK.
# False answer: Have a desire to make a difference.
# 16  False answer: They ignored others' ungreen behavior.
# False answer: They chose better chemical cleaners.
# False answer: They sold their home-made food.
# 17  False answer: By helping to keep public order.
# False answer: By helping to catch criminals.
# False answer: By helping to keep public places clean.
# 18  False answer: 1714
# False answer: 1782
# False answer: 1872
# 19  False answer: To prevent sunburn and skin cancers.
# False answer: To protect the sensitive cells of the skin.
# False answer: To prevent the skin from being damaged by the UV rays of the sun.
# 20  False answer: Edmund & Daniel.
# False answer: Jim & Alex.
# False answer: Daniel & Emmy.
# 21  False answer: They were angry and frightened.
# False answer: They were sad and disappointed.
# False answer: They were sorry and worried.
# 22  False answer: It is very cute and lovely.
# False answer: It never breaks the eggs in the game.
# False answer: It can do many things faster than humans.
# 23  False answer: Entertainment and sports.
# False answer: Education and culture.
# False answer: Nature and environment.
# 24  False answer: August 15.
# False answer: September 29.
# False answer: November 21.
# 25  False answer: Statue of Liberty.
# False answer: Hagley Museum.
# False answer: The New York Botanical Garden.
# 26  False answer: To show her support for him.
# False answer: To show she was also a survivor.
# False answer: To show she was a role model for him.
# 27  False answer: The company will pay for the faulty air conditioner.
# False answer: The customer will take legal action.
# False answer: The Internet service will be interrupted.
# 28  False answer: To attract the customer back.
# False answer: To apologize for the poor service.
# False answer: To persuade the customer to buy their products.
# 29  False answer: Both were written by the same person.
# False answer: Both were sent by the same company.
# False answer: Both were sent to the same person.
# 30  False answer: Permissive parenting.
# False answer: Tiger Mom parenting.
# False answer: French parenting.
# 31  False answer: You can choose any of the towers.
# False answer: It is designed for big families.
# False answer: Every room has a walkway.
# 32  False answer: http://www.icehotel.com
# False answer: http://www.ariautowers.com
# False answer: http://www.propeller-island.com
# 33  False answer: Propeller Island.
# False answer: Ariau Amazon Towers.
# False answer: Bahama Beach Club.
# 34  False answer: He helped his parents clean up.
# False answer: He asked his parents to excuse his grandpa.
# False answer: He didn't speak to his parents for a day.
# 35  False answer: Because he was unhappy with his life.
# False answer: Because he was unhappy with his family.
# False answer: Because he was made to break a dish.
# 36  False answer: The photos of other kids.
# False answer: The comments of other kids.
# False answer: The authority's apology.
# 37  False answer: It will be popular in all the universities.
# False answer: It will be used only to take attendance.
# False answer: It will be banned from the Japanese universities.
# 38  False answer: In the desert.
# False answer: In the air.
# False answer: In the seas, rivers and lakes.
# 39  False answer: To give a warning about the common causes of childhood injury.
# False answer: To give the statistics of childhood injury and death.
# False answer: To give the causes of the accidents.
# 40  False answer: Children should not be allowed to swim alone.
# False answer: The most common causes of non-deadly injury for children are falls and bike accidents.
# False answer: The combination of window guards and childproof gates can effectively prevent falls.
# 41  False answer: To use a content screener to select the sites.
# False answer: To put the computer in a child's room.
# False answer: To ask the children not to talk to strangers on-line.
# 42  False answer: Joyful jugglers.
# False answer: Tour of love.
# False answer: Army artist.
# 43  False answer: 6502-3984.
# False answer: 6802-2530.
# False answer: 8403-3500.
# 44  False answer: Her mom's advice.
# False answer: Her college education.
# False answer: Her love for music.
# 45  False answer: Being serious in her work.
# False answer: Being careful in her behavior.
# False answer: Being brave in facing difficulties.
# 46  False answer: title and description of duties
# False answer: skills and flexibility with regard to study/exam timetables
# False answer: location of the work
# 47  False answer: By praising their effort and progress.
# False answer: By emphasizing their children's "smartness".
# False answer: By letting kids know that everything is within their control.
# 48  False answer: His father.
# False answer: Some emergency officials.
# False answer: More than 100 volunteers.
# 49  False answer: The sickness.
# False answer: The bad weather.
# False answer: The bad habit.
# 50  False answer: They want to discover what the interviewees know.
# False answer: They are curious about the answers.
# False answer: They just ask questions without thinking much.
# 51  False answer: The children's cries for help.
# False answer: The sound of the burning truck.
# False answer: The smell of the burning rubber.
# 52  False answer: He poured water on Ronnie's legs.
# False answer: He tore off Ronnie's burning clothes.
# False answer: He put Ronnie's legs in cold water.
# 53  False answer: Because her daughter was lost.
# False answer: Because her daughter was injured.
# False answer: Because her daughter was found.
# 54  False answer: He was playing happily with his friends outside his grandmother's apartment building.
# False answer: He was searching for Jocelyn in the neighborhood.
# False answer: He was cycling around the corner to get his bicycle.
# 55  False answer: By adding more functions to it.
# False answer: By improving its performance.
# False answer: By changing its design.
# 56  False answer: Life is Beautiful
# False answer: Verona
# False answer: Shawshank Redemption
# 57  False answer: Andy was released from the prison.
# False answer: Red got murdered by the guards.
# False answer: The film ended with a happy note.
# 58  False answer: Each family has a beautiful yard.
# False answer: People take care of the environment as their own garden.
# False answer: There are many retired people in the community.
# 59  False answer: How do you do? Do you come here from America?
# False answer: Do you like China?
# False answer: Where are you from?
# 60  False answer: To talk about his personal life.
# False answer: To talk about his job.
# False answer: To invite him to watch a football game.
# 61  False answer: By sending him to a special school.
# False answer: By teaching him how to use a computer.
# False answer: By buying him many different kinds of toys.
# 62  False answer: When he was born.
# False answer: When he was10 years old.
# False answer: When he was5 years old.
# 63  False answer: Sydney and Byron Bay
# False answer: Byron Bay and Cairns
# False answer: Sydney and Cairns
# 64  False answer: Sydney
# False answer: Byron Bay
# False answer: The Daintree Rainforest
# 65  False answer: The long distance.
# False answer: The heavy traffic.
# False answer: The bad weather.
# 66  False answer: He is a CEO of a big company.
# False answer: He has been writing positive blogs for a long time.
# False answer: He has been giving advice on his blog for a long time.
# 67  False answer: 700.
# False answer: 140,000.
# False answer: 400,000.
# 68  False answer: 1964; Alaska.
# False answer: 1923; Japan.
# False answer: 1976; China.
# 69  False answer: To collect coins for the project.
# False answer: To donate some of their collections to the school.
# False answer: To donate some of their favorite books to the school.
# 70  False answer: They will be very happy to see the book.
# False answer: They may give the books to their daughters.
# False answer: They will keep the books for themselves.
# 71  False answer: 50 cents.
# False answer: 75 cents.
# False answer: $1.25.
# 72  False answer: $10.50.
# False answer: $22.25.
# False answer: $35.00.
# 73  False answer: $10.50
# False answer: $12.50
# False answer: $11.50
# 74  False answer: More and more people are practicing judo.
# False answer: More and more people are learning self-defense.
# False answer: More and more people are using guns to defend themselves.
# 75  False answer: Two
# False answer: Three
# False answer: Five
# 76  False answer: Give women equal pay for equal work.
# False answer: Make sure all Americans have access to paid family leave.
# False answer: Pre-K for our kids.
# 77  False answer: 8:30a.m.--10:00a.m..
# False answer: 10:30a.m.--3:00p.m..
# False answer: 1:30p.m.--3:15p.m..
# 78  False answer: By expanding his store.
# False answer: By accepting Julie's idea.
# False answer: By getting a better price for his produce.
# 79  False answer: A news story
# False answer: A science fiction
# False answer: A medical textbook
# 80  False answer: In the town hall.
# False answer: In the school building.
# False answer: Near the community arts centre.
# 81  False answer: Doubtful.
# False answer: Disappointed.
# False answer: Positive.
# 82  False answer: To ask them for authorization.
# False answer: To remind them to donate blood immediately.
# False answer: To tell them the levels of blood groups.
# 83  False answer: Because the students were all astronauts.
# False answer: Because the teacher was a woman.
# False answer: Because the class was held in a space station.
# 84  False answer: Because they lack practical experience.
# False answer: Because they earn three to four times as much money as Chinese residents.
# False answer: Because they are not willing to work as executives.
# 85  False answer: the federal government
# False answer: the state government
# False answer: the city government
# 86  False answer: Property tax.
# False answer: Sales tax.
# False answer: Income tax.
# 87  False answer: it would have meant hundreds of lorries a day
# False answer: it would have been too costly
# False answer: the local people were strongly against it
# 88  False answer: To build a large incinerator plant
# False answer: To lave a huge waste site near Portobello
# False answer: To persuade the EU to change its policy
# 89  False answer: Blaming someone or something outside of themselves.
# False answer: Taking responsibility for their life.
# False answer: Living life "on purpose".
# 90  False answer: A description of how a new discovery could be made.
# False answer: A guess about what the future will bring.
# False answer: A warning about the dangers of emerging technologies.
# 91  False answer: The English Channel Tunnel.
# False answer: The Turin-Lyon Tunnel.
# False answer: The Xiamen-Jinmen tunnel.
# 92  False answer: The lack of money for the project.
# False answer: The technical problems with the tunnel.
# False answer: The length of the tunnel.
# 93  False answer: Those whose diet contains a lot of meat and sugar.
# False answer: Those whose diet contains a lot of vegetables and white bread.
# False answer: Those whose diet contains a lot of white bread and black tea.
# 94  False answer: Three.
# False answer: Four.
# False answer: Five.
# 95  False answer: requiring Chinese computer makers to load legal software on their machines
# False answer: moving against software pirates all the time
# False answer: honoring words in protecting intellectual property rights
# 96  False answer: Because he got a half-dollar for the first time in his life .
# False answer: Because he got a hug from a stranger .
# False answer: Because he realized he was loved by many people .
# 97  False answer: Reducing the weight of English in China.
# False answer: Improving the design of the curriculum.
# False answer: Giving English an equal amount of emphasis.
# 98  False answer: In a restaurant.
# False answer: On a farm.
# False answer: In a car.
# 99  False answer: Because it has led to the students being drunk and killing others.
# False answer: Because it has made the students lose their interest in studies.
# False answer: Because it has made the students take into the extreme.
# 100  False answer: Not forgetting the names of the people you want to give gifts to.
# False answer: Doing the math to make sure that you spend money correctly.
# False answer: Making sure that you spend enough money on each person.
# 101  False answer: The fear center in the brain can store different kinds of memories.
# False answer: The behavior therapy can help people suffering from mental illness.
# False answer: Calcium-permeable AMPARs can be formed in the fear center of the brain.
# 102  False answer: It is a good way to treat mental diseases.
# False answer: It is a way to completely change people's lives.
# False answer: People may suffer from mental diseases in the future.
# 103  False answer: At about 7:30 pm.
# False answer: At about 8:45 pm.
# False answer: At about 9:15 pm.
# 104  False answer: $75.
# False answer: $75.
# False answer: $41.
# 105  False answer: In 1044.
# False answer: In 716.
# False answer: In the Three Kingdoms Period.
# 106  False answer: Because three railway workers stumbled upon hot springs.
# False answer: Because it was the first national park of Canada.
# False answer: Because it was the oldest national park of Canada.
# 107  False answer: By giving the buyer a cash discount.
# False answer: By giving the buyer a charge slip.
# False answer: By giving the bank a percentage of the sales.
# 108  False answer: It is difficult to make the payments on time
# False answer: Interest rates are very high
# False answer: It is hard to get a credit card without a credit history
# 109  False answer: The standard of refereeing is very high.
# False answer: The standard of refereeing will be even higher at the next World Cup.
# False answer: The physical condition is the chief consideration in choosing a football referee.
# 110  False answer: To be in love is to be subject to great emotional ups and downs.
# False answer: To love someone means to put up with his/her shortcomings.
# False answer: To be patient means to have a strong sense of responsibility.
# 111  False answer: Their being of different social status.
# False answer: Their being too young.
# False answer: Their not having similar hopes and dreams.
# 112  False answer: Joan Winterkorn.
# False answer: Gabriel Heaton.
# False answer: Slaman Rushdie.
# 113  False answer: You should shake hands with your boss.
# False answer: You should apologize to your boss.
# False answer: You should introduce your self first.
# 114  False answer: He thought it was very good.
# False answer: He thought it was not useful.
# False answer: He thought it was very useful.
# 115  False answer: They owned a public house there.
# False answer: They came to take up a challenge.
# False answer: They were invited by the university.
# 116  False answer: Artists from around the world.
# False answer: The public of Edinburgh.
# False answer: The actors from the theatre.
# 117  False answer: He gave up acting and basketball and focused on his studies.
# False answer: He fought back by showing his talents in both basketball and acting.
# False answer: He went on to study film at the University of Southern California.
# 118  False answer: They lost heart, and gave up their dreams.
# False answer: They became more careful in their work.
# False answer: They were angry, and decided not to cooperate with others any more.
# 119  False answer: Parents
# False answer: Professors
# False answer: Housewives
# 120  False answer: The government.
# False answer: Teachers.
# False answer: Censors.
# 121  False answer: He thinks they are a bad idea.
# False answer: He is indifferent   to them.
# False answer: He thinks they are not popular.
# 122  False answer: Children pay attention to the adult television show.
# False answer: The distraction of the background noise has a positive effect on children's development.
# False answer: Children's ability to focus is better when the TV is off.
# 123  False answer: They will be punished if they lie to the patients.
# False answer: They will take no interest in their patients.
# False answer: They will not know the real cause of the patients' diseases.
# 124  False answer: Add patients as friends on Facebook.
# False answer: Hug and kiss patients.
# False answer: Call patients by their first names.
# 125  False answer: Doctors should avoid adding patients as friends on Facebook.
# False answer: Doctors should not hug or allow patients to call them by their first names.
# False answer: Those who break the boundaries will face some punishment.
# 126  False answer: provide personalized instruction
# False answer: provide feedback to the students
# False answer: react to the students' facial expression
# 127  False answer: To ask for her address.
# False answer: To say "Have a nice day"
# False answer: To say he was sorry.
# 128  False answer: Be careful while you are walking on the street.
# False answer: Try to help those who are in trouble.
# False answer: Be kind to everyone you meet.
# 129  False answer: Because they are more likely to get angry.
# False answer: Because they are more likely to get tired.
# False answer: Because they are more likely to get stressed.
# 130  False answer: Because Taiwan fishing boats sailed to the islands to protest Japan.
# False answer: Because Taiwanese are demonstrating against Japan's "purchase".
# False answer: Because Japan is China's largest trade partner.
# 131  False answer: They were angry with him.
# False answer: They wanted to steal his camera.
# False answer: The reporter took their picture.
# 132  False answer: A newspaper.
# False answer: A TV interview.
# False answer: A local guide.
# 133  False answer: Surprised
# False answer: Excited
# False answer: Nervous
# 134  False answer: The iPhone.
# False answer: The Blackberry.
# False answer: The Android.
# 135  False answer: A new language learning method.
# False answer: A community of language learners.
# False answer: A global language learning network.
# 136  False answer: By using the same plants.
# False answer: By making sounds.
# False answer: By using telephones.
# 137  False answer: In the dust under the old lady's seat.
# False answer: On the floor near the old lady's feet.
# False answer: In the crack of the airplane floor near her seat.
# 138  False answer: In a news report.
# False answer: In a fashion magazine.
# False answer: In a novel book.
# 139  False answer: Try not to think about it.
# False answer: Close your eyes and imagine it going well.
# False answer: Think about how the flight or job interview is going to happen.
# 140  False answer: History and language.
# False answer: Engineering.
# False answer: Saudi Arabia.
# 141  False answer: About 10 years.
# False answer: About 20 years.
# False answer: About 30 years.
# 142  False answer: four
# False answer: six
# False answer: seven
# 143  False answer: The difference of music.
# False answer: The common types of music.
# False answer: The benefits of music.
# 144  False answer: 75
# False answer: 100
# False answer: 250
# 145  False answer: The mirror.
# False answer: The counter.
# False answer: The medicine.
# 146  False answer: By pouring the breakfast into a bowl.
# False answer: By listening to the doctor's advice.
# False answer: By testing the food supplies in the kitchen.
# 147  False answer: In order of frequency.
# False answer: In order of preference.
# False answer: In order of importance.
# 148  False answer: It will create more jobs for college graduates.
# False answer: It will help students become more confident.
# False answer: It will make students' education more complete.
# 149  False answer: It is a kind of sense which can feel the coming of disaster.
# False answer: It is a kind of sense which can help animals to avoid danger.
# False answer: It is a kind of sense which can tell that something is going to happen.
# 150  False answer: Environment.
# False answer: Education.
# False answer: Entertainment.
# 151  False answer: it is used in jewelry making
# False answer: it is easy to get
# False answer: it is used as a medicine
# 152  False answer: Chinese people were forbidden to wear silk.
# False answer: Chinese scientists successfully kept the secret from the West.
# False answer: The secret of silk production was not written down.
# 153  False answer: Melbourne is the most beautiful city in the world.
# False answer: Australians love to go to the beach and play sports outdoors.
# False answer: The Australian government is trying to attract more immigrants.
# 154  False answer: He wanted to play with the dog.
# False answer: He wanted to make the dog dirty.
# False answer: He wanted to make his mother unhappy.
# 155  False answer: Daniel put the dog Jasper into the washing machine.
# False answer: Daniel cut off the hair of the girl next door.
# False answer: Daniel put the sink into the flooding state.
# 156  False answer: The public has realized the importance of public transit.
# False answer: The public has got a lot more money to support public transit.
# False answer: The public is much less car-oriented now.
# 157  False answer: Before the volcano broke out .
# False answer: As soon as the volcano broke out .
# False answer: After the volcano stopped rushing up .
# 158  False answer: Taking its first major step to launching an online operation with the acquisition of internet retailer
# False answer: Opening three convenience stores, around 3,000 sq ft in size, in July under the name M Local
# False answer: Acquiring internet retailer Kiddicare for PS70 million
# 159  False answer: Because they are not safe to eat.
# False answer: Because they are not different from other food.
# False answer: Because they are not needed.
# 160  False answer: It is hot water.
# False answer: It is deep water.
# False answer: It is in hot water.
# 161  False answer: Children aged 4 to 9.
# False answer: Children aged 9 to 14.
# False answer: Children aged up to 4.
# 162  False answer: To show his idea is practical.
# False answer: To help him find new reasons to make the shoes.
# False answer: To keep the office tidy and clean.
# 163  False answer: Chinese ink & water painting class
# False answer: Acrobatic show
# False answer: Ten yuan (US$1.2) for a cup of Chinese tea
# 164  False answer: It is important for students to take part in the test preparation.
# False answer: Students who take part in the test preparation have more chances of getting high scores.
# False answer: Students who take part in the test preparation have more opportunities to learn.
# 165  False answer: It improves the environment.
# False answer: It increases economic productivity.
# False answer: It reduces birth rates.
# 166  False answer: 4
# False answer: 8
# False answer: 12
# 167  False answer: How to make an adventure movie.
# False answer: How to make ice cream alive.
# False answer: The steps to make a film.
# 168  False answer: The young archer died from the wound soon after.
# False answer: The king declared the young man the greatest archer.
# False answer: The young archer found the old man's master and killed him.
# 169  False answer: Seven years.
# False answer: Eight years.
# False answer: More than ten years.
# 170  False answer: Different CDs.
# False answer: Different videos.
# False answer: Different electronics.
# 171  False answer: More than 300,000 people die annually from global warming.
# False answer: The economic losses from global warming have reached $125 billion.
# False answer: The number of deaths from global warming is expected to double by 2030.
# 172  False answer: It is invalid in terms of conclusions.
# False answer: It is deeply flawed in terms of contents.
# False answer: It is highly controversial in terms of effects.
# 173  False answer: It is deeply flawed because there is no way to distinguish deaths related to human-driven global warming.
# False answer: It is an embarrassment because it is not a scientific report at all.
# False answer: It is aimed at proving that human beings are largely to blame for climate change.
# 174  False answer: How to draft a new international climate treaty.
# False answer: How to distinguish deaths related to global warming from other deaths.
# False answer: How many people will be affected by global warming by 2030.
# 175  False answer: Because there are too many polar bears.
# False answer: Because there are not enough places for them to live on.
# False answer: Because there are too many seals on the land.
# 176  False answer: Bozeman.
# False answer: Clemmons.
# False answer: Lisa Bowbin.
# 177  False answer: Shout or whistle twice.
# False answer: Shout or whistle three times together.
# False answer: Make some gunshots.
# 178  False answer: Shout loudly.
# False answer: Walk away.
# False answer: Get help quickly.
# 179  False answer: Walk away from your friends.
# False answer: Make a little house and cover up the holes with branches.
# False answer: Pick off small branches and drop them as you walk.
# 180  False answer: His father was a football player.
# False answer: His parents were very poor.
# False answer: He played football with his father.
# 181  False answer: She was too angry to notice it.
# False answer: She wanted to finish her book first.
# False answer: She wanted to enjoy the cookies quietly.
# 182  False answer: The 1st one.
# False answer: The 3rd one.
# False answer: The 4th one.
# 183  False answer: Because she has been running her stall for forty years.
# False answer: Because she is good at running a business.
# False answer: Because she has been working hard for many years.
# 184  False answer: Because she wanted to keep it as a souvenir.
# False answer: Because she wanted to make a new friend.
# False answer: Because she wanted to make a gesture of goodwill.
# 185  False answer: Chips are what we are born with.
# False answer: Chips will be used in re-engineering the brain.
# False answer: Chips will play the leading role in our lives.
# 186  False answer: There will be no more males.
# False answer: Females will have no more female children.
# False answer: The world will be full of people who want to get to Heaven.
# 187  False answer: He walked away from her.
# False answer: He didn't speak to her.
# False answer: He turned bright red.
# 188  False answer: he had seen enough of Europe
# False answer: he had to stay with his parents
# False answer: he couldn't afford another ticket
# 189  False answer: To travel to southern France.
# False answer: To escape the guided tour.
# False answer: To do something different.
# 190  False answer: he could take pride in himself
# False answer: he could be as independent as other Inter-Railers
# False answer: he could travel at a faster speed
# 191  False answer: Feeding your pet in the toilet.
# False answer: Sharing your food with your pet.
# False answer: Giving your pet raw meat.
# 192  False answer: The volunteers can only eat space food.
# False answer: The volunteers can only shower every 10 days.
# False answer: The volunteers can experience a lot: flying to Mars, flying back and working on Mars.
# 193  False answer: ten times a day
# False answer: once a week
# False answer: twice a week
# 194  False answer: newspapers
# False answer: books
# False answer: travel guidebooks
# 195  False answer: Ghana
# False answer: Vietnam
# False answer: Indonesia
# 196  False answer: About eight years.
# False answer: About ten years.
# False answer: About fourteen years.
# 197  False answer: They don't pay attention to their individual differences.
# False answer: They don't allow them to have any hobbies.
# False answer: They force them to work harder and harder.
# 198  False answer: That they have to do well in high school.
# False answer: That they realize they have a slim chance of getting into a top university.
# False answer: That they put a lot of stress on themselves and stay in a nervous state day after day.
# 199  False answer: One
# False answer: Two
# False answer: Four
# 200  False answer: To have a delicious breakfast.
# False answer: To bid on the flower arrangements.
# False answer: To make a centerpiece using things found in the home.
# 201  False answer: 9:00 a.m. ~ 10:30 a.m.
# False answer: 12:00 p.m. ~ 1:00 p.m.
# False answer: 3:00 p.m. ~ 4:00 p.m.
# 202  False answer: Hoover became a famous person.
# False answer: The speech became more interesting.
# False answer: Hoover's reputation improved.
# 203  False answer: In 1983
# False answer: In 1985
# False answer: In 1989
# 204  False answer: When Lang was 5
# False answer: When Lang was 9
# False answer: When Lang was 17
# 205  False answer: He was very successful
# False answer: He had no lessons
# False answer: He had no one to help him
# 206  False answer: William
# False answer: Terence Tao
# False answer: Albert Einstein
# 207  False answer: 18 to 29.
# False answer: 30 to 49.
# False answer: 50 to 64.
# 208  False answer: I know what you are going through.
# False answer: This happened to me.It might help you.
# False answer: I've noticed lately that you seem down.I care about you and would like to listen to what you're thinking about.
# 209  False answer: We should take a good rest every night.
# False answer: We should eat a lot of fruit and vegetables.
# False answer: We should do some exercises every day.
# 210  False answer: less than 22
# False answer: more than 126
# False answer: less than 100
# 211  False answer: I want to buy some vodka.
# False answer: I have too many lawyers in my country.
# False answer: We have too many lawyers in my country.
# 212  False answer: Because she was too tired and cold.
# False answer: Because the sea was like an ice bath.
# False answer: Because sharks were swimming toward her.
# 213  False answer: By doing experiments.
# False answer: By collecting and writing blood samples.
# False answer: By making estimates.
# 214  False answer: They spend much more time reading books.
# False answer: They tend to spend more time on Internet.
# False answer: They have less interest in reading books.
# 215  False answer: The Internet is a wonderful place for kids.
# False answer: Kids are spending more time online.
# False answer: Kids are reading less because they're online.
# 216  False answer: Her son's not being polite enough.
# False answer: Her son's not finishing his meal.
# False answer: Her son's not waiting for her.
# 217  False answer: Because she wanted to buy some food for lunch.
# False answer: Because she wanted to buy some food for supper.
# False answer: Because she wanted to buy something for a present.
# 218  False answer: Because they have a gift for self-promotion.
# False answer: Because they have so much money to throw around.
# False answer: Because their products are overpriced.
# 219  False answer: feet---shoulders---legs---wrists
# False answer: wrists---legs---shoulders---feet
# False answer: feet---shoulders---wrists---legs
# 220  False answer: She was unhappy and refused to accept the result.
# False answer: She was optimistic and tried to get used to it.
# False answer: She was unhappy and refused to accept the result.
# 221  False answer: To be a cheerleader.
# False answer: To remove the prostheses.
# False answer: To win a cheerleading tournament.
# 222  False answer: First Aid for Pets
# False answer: Signs of Shock
# False answer: Transporting Pets
# 223  False answer: The air is clearer then.
# False answer: The sun is up for longer periods then.
# False answer: The clouds are less likely to interfere then.
# 224  False answer: They go ice skating in the city.
# False answer: They take photos of the beautiful scenery.
# False answer: They visit the museums and galleries.
# 225  False answer: The advantages of traveling in winter in Iceland.
# False answer: The latest news about the volcanoes in Iceland.
# False answer: The precautions to be taken before a trip to Iceland.
# 226  False answer: Her daily life.
# False answer: Her achievements.
# False answer: Her goals for the day.
# 227  False answer: Red Sorghum.
# False answer: The Hero.
# False answer: The World.
# 228  False answer: Because his social criticism is helpful to his homeland.
# False answer: Because he created a world reminiscent in its complexity of Faulkner and Garcia Marques.
# False answer: Because he is the first Chinese resident to win the prize.
# 229  False answer: Go to the hospital directly.
# False answer: Ask some friends to visit him at home.
# False answer: Tell him not to go out in cold weather.
# 230  False answer: minimum price
# False answer: ban on drinking games
# False answer: Home Secretary
# 231  False answer: Churchill was too busy to go to the play.
# False answer: Churchill's play was not worth seeing.
# False answer: Churchill's friend would go to the play with him.
# 232  False answer: He didn't want to go to the play.
# False answer: He had already bought the tickets for the second night.
# False answer: He had no time to go to the play.
# 233  False answer: Some pictures.
# False answer: DV films.
# False answer: Japanese cartoons.
# 234  False answer: Lin says QQ is very helpful to their friendships.
# False answer: Tang says QQ is a good space for them to make a record of their lives.
# False answer: Tang says he chats on QQ on weekdays though he has lots of homework.
# 235  False answer: Nothing.
# False answer: A box.
# False answer: Paper.
# 236  False answer: Because they are underweight.
# False answer: Because they have no food to eat in school.
# False answer: Because they have to look after their younger brothers and sisters.
# 237  False answer: He wanted to learn English well
# False answer: He was good at driving
# False answer: He was a taxi driver in South Carolina
# 238  False answer: She had swallowed something dangerous.
# False answer: She had fainted because of hunger.
# False answer: She had been knocked down by a car.
# 239  False answer: Hold the salt shaker in hand.
# False answer: Cook tasty food at home.
# False answer: Buy salt at the market.
# 240  False answer: Because they don't like their childhood nickname.
# False answer: Because they don't want to be seen with their parents.
# False answer: Because they are afraid of their parents' behavior.
# 241  False answer: He felt embarrassed when he was 14.
# False answer: He felt his father was very silly when he was young.
# False answer: He thought his father was self-sufficient when he was 14.
# 242  False answer: Summer.
# False answer: Spring.
# False answer: Autumn.
# 243  False answer: Because she can't find a suitable job in the UK.
# False answer: Because she has to return to her hometown.
# False answer: Because she has to do two years' work experience.
# 244  False answer: In a science fiction.
# False answer: In a travel magazine.
# False answer: In a textbook.
# 245  False answer: All the citizens.
# False answer: The poor men.
# False answer: Only the men who owned property.
# 246  False answer: Because it is held at the town hall.
# False answer: Because it is held at a stated time.
# False answer: Because it is held in the central square.
# 247  False answer: was sleeping with her baby
# False answer: was protecting her baby well
# False answer: was badly injured but alive
# 248  False answer: was awake
# False answer: was calm
# False answer: was frightened
# 249  False answer: Community reconstruction.
# False answer: Community activities.
# False answer: Eco-village.
# 250  False answer: Ireland
# False answer: Spain
# False answer: France
# 251  False answer: Health
# False answer: Income
# False answer: Environment
# 252  False answer: The class,age and race barriers in the USA.
# False answer: The history of the Augusta Golf Club.
# False answer: The racist remarks made by a chairman of the club.
# 253  False answer: became the youngest professional golfer ever.
# False answer: astonished the world by winning the Masters Colf Tournament.
# False answer: was the founder of the Masters Tournament.
# 254  False answer: Because they are worried about what may or may not happen tomorrow.
# False answer: Because they are old and have no guarantee that they will be here tomorrow.
# False answer: Because they are busy making other plans and their efforts will pay off.
# 255  False answer: People who live in the south of Springfield.
# False answer: People who have nothing to do that evening.
# False answer: People who are in the open house at the school.
# 256  False answer: $4.75
# False answer: $6.75
# False answer: $10.00
# 257  False answer: To help the growth of small side branches.
# False answer: To make the tree healthier.
# False answer: To make the area which has been pruned, smooth and clean.
# 258  False answer: They should download an application form.
# False answer: They should visit the ad website.
# False answer: They should call the ad telephone number.
# 259  False answer: The courses are free.
# False answer: The earlier the better.
# False answer: The applicants can pay in advance.
# 260  False answer: They jumped out of the window.
# False answer: They were taken out by their families.
# False answer: They were taken out by other people.
# 261  False answer: He was very happy.
# False answer: He was very calm.
# False answer: He was very surprised.
# 262  False answer: She was an only child.
# False answer: She was a girl.
# False answer: She was poor.
# 263  False answer: They all support the rich people of Gangnam.
# False answer: They can understand the language of the song.
# False answer: They all like PSY's songs.
# 264  False answer: They wanted to attract supporters.
# False answer: They wanted to learn PSY's moves.
# False answer: They wanted to show their rich life.
# 265  False answer: PSY's life in Gangnam.
# False answer: The special dance moves of PSY.
# False answer: The funny horse riding style of PSY.
# 266  False answer: They thought the man was a fool.
# False answer: They didn't think the man was honest.
# False answer: They didn't think the man was a good plant.
# 267  False answer: She wanted to help the poor people.
# False answer: She wanted to work independently.
# False answer: She wanted to dress like a nun.
# 268  False answer: She wanted to dress like the Indians.
# False answer: She wanted to work independently.
# False answer: She was sent to India by the Pope.
# 269  False answer: By listening to the cassettes read to her.
# False answer: By studying the anatomy, physiology and other health sciences.
# False answer: By taking part in medical research.
# 270  False answer: Wired and InStyle.
# False answer: Discover and InStyle.
# False answer: Self and Discover.
# 271  False answer: A novel
# False answer: A travel guide
# False answer: A business magazine
# 272  False answer: the city's economic problems
# False answer: the city's losing its mills
# False answer: the city's population loss
# 273  False answer: Because China is the "kingdom of bicycle".
# False answer: Because the electric bike production in China accounts for about 90% of the world's total.
# False answer: Because the country wants to reduce the amount of energy consumption by 20%.
# 274  False answer: Carbonated and sports drinks.
# False answer: Fruit juice and energy drinks.
# False answer: Sports drinks and bottled water.
# 275  False answer: Fruit juice.
# False answer: Carbonated soft drinks.
# False answer: Bottled water.
# 276  False answer: Before they graduated.
# False answer: After they had their jobs.
# False answer: After they had their complaints.
# 277  False answer: Because the professor was too poor to afford porcelain.
# False answer: Because the professor wanted to show his guests' status.
# False answer: Because the professor wanted to create a conflict.
# 278  False answer: The large pot of hot chocolate.
# False answer: The conversation about life.
# False answer: Their visit to his university.
# 279  False answer: They couldn't find their way around in the new building.
# False answer: The new systems were not easy to use and understand.
# False answer: The new building was too crowded and hot.
# 280  False answer: College graduates from the West.
# False answer: Women from the Midwest.
# False answer: Men from the South.
# 281  False answer: We can't call any numbers by mistake.
# False answer: We can't find any numbers we need quickly.
# False answer: We can't dial the numbers according to the order.
# 282  False answer: All of them are in the same area.
# False answer: All of them offer the same service.
# False answer: They all have an outdoor pool.
# 283  False answer: Pingviman Hotel and Home-style Thai.
# False answer: Art Mai Gallery Nimman Hotel and At Chiang Mai.
# False answer: Chang Khlan Hotel and De Chai The Colonial Hotel.
# 284  False answer: speed and G-forces
# False answer: audio-visual technologies
# False answer: robotics
# 285  False answer: Because they want to breathe fresh air outside.
# False answer: Because there's a fire in the living room.
# False answer: Because they wear heavy clothes all day long.
# 286  False answer: Tesco removed the burgers from the shelves.
# False answer: Customers could get a refund for the burgers.
# False answer: Horsemeat was found in frozen porkburgers.
# 287  False answer: It apologized to the customers and refunded their money.
# False answer: It removed the beefburgers from the shop shelves immediately.
# False answer: It worked harder to make sure this never happened again.
# 288  False answer: Everyone can be sure that the products they buy contain what it says on the label.
# False answer: It will be hard for Tesco to get the people's trust back.
# False answer: The food they buy actually contains what it says on the label.
# 289  False answer: $28
# False answer: $38
# False answer: $42
# 290  False answer: They can see a doctor free of charge.
# False answer: They can see a doctor when they are sick.
# False answer: They can see a doctor when they are hurt.
# 291  False answer: 7 days
# False answer: 8 days
# False answer: 9 days
# 292  False answer: Outside the Castle
# False answer: In the Castle Shop
# False answer: In the Rose Garden
# 293  False answer: Because they have large quantities of goods.
# False answer: Because they can get goods at a very low cost.
# False answer: Because they can sell their products at a higher price.
# 294  False answer: 5628
# False answer: 4753
# False answer: 1313
# 295  False answer: Students' attitude toward their parents.
# False answer: Students' love for their parents.
# False answer: Students' desire for a high degree.
# 296  False answer: Three.
# False answer: Two.
# False answer: One.
# 297  False answer: encourage people to be more aware of their surroundings.
# False answer: teach people how to buy cars
# False answer: find out the good people who are in difficult situations.
# 298  False answer: She asked another student.
# False answer: She drank it in front of her.
# False answer: She knew it from the teacher's phone.
# 299  False answer: To help Newtown Creek Wastewater Treatment Plan become more popular.
# False answer: To help make methane to heat homes.
# False answer: To help Newtown Creek Wastewater Treatment Plan make more money.
# 300  False answer: It has no good locations.
# False answer: It has no budget to build plants.
# False answer: It has no way to get organic waste.
# 301  False answer: To deal with the safety problems.
# False answer: To deal with the environmental pollution.
# False answer: To find ways to make money.
# Token indices sequence length is longer than the specified maximum sequence length for this model (1106 > 1024). Running this sequence through the model will result in indexing errors
# 302  False answer: Dogs that can help deaf people communicate.
# False answer: Dogs that can help paralyzed people write.
# False answer: Dogs that can help disabled people do shopping.
# 303  False answer: 3
# False answer: 4
# False answer: 6
# 304  False answer: Because he wanted to show his toys to his friends.
# False answer: Because he wanted to play with his toys instead of working.
# False answer: Because he wanted to keep his toys as treasures.
# 305  False answer: His eagerness to make friends with Tom.
# False answer: His love for all kinds of interesting plans.
# False answer: His great desire to go swimming with Tom.
# 306  False answer: Bob was great to build this bridge.
# False answer: John and Bob were great friends.
# False answer: Bob was great at building bridges.
# 307  False answer: To save money
# False answer: To protect the environment
# False answer: To deal with the drought
# 308  False answer: We should work hard all our lives.
# False answer: We should read many books.
# False answer: We should do thousands of experiments.
# 309  False answer: Its long life.
# False answer: Its cheapness.
# False answer: Its durability.
# 310  False answer: Making a new kind of computer case.
# False answer: Creating a new material to replace plastic.
# False answer: Working on ways to improve its toughness.
# 311  False answer: There will be no more demand for coffee.
# False answer: The price of coffee will go up all the time.
# False answer: People will stop drinking coffee.
# 312  False answer: A young woman was seriously injured by a fly.
# False answer: A young woman was killed by a customer's bullet.
# False answer: A young woman was killed by a customer.
# 313  False answer: Because she paid the money back.
# False answer: Because the owner was unhappy with her.
# False answer: Because she was a former frequent customer of the restaurant.
# 314  False answer: People.
# False answer: Economy.
# False answer: Culture.
# 315  False answer: They wanted to promote a new holiday.
# False answer: They wanted to encourage people to talk like pirates.
# False answer: They wanted to invent a story about pirates.
# 316  False answer: meet Australian and British History
# False answer: get information about famous people from the Museum
# False answer: take photos of the Museum with your camera
# 317  False answer: William.
# False answer: Richard.
# False answer: Lance.
# 318  False answer: A deep sleep.
# False answer: A light sleep.
# False answer: A sound sleep.
# 319  False answer: 6 hours.
# False answer: 8 hours.
# False answer: 9 hours.
# 320  False answer: Being in good shape.
# False answer: Having more energy.
# False answer: Improving your memory.
# 321  False answer: They had high blood pressure.
# False answer: They were unhealthy in tests for high blood pressure.
# False answer: They had evidence of problems in heart disease.
# 322  False answer: They were excited.
# False answer: They were angry.
# False answer: They were happy.
# 323  False answer: York Theatre Royal.
# False answer: Grand Theatre.
# False answer: City Varieties.
# 324  False answer: 452116
# False answer: 365998
# False answer: 502116
# 325  False answer: Teachers only.
# False answer: Students only.
# False answer: Neither students nor teachers.
# 326  False answer: 5 years
# False answer: 5 weeks
# False answer: 5 hours
# 327  False answer: About 33
# False answer: About 18
# False answer: About 5
# 328  False answer: The way they felt
# False answer: The way they acted
# False answer: The Internet database
# 329  False answer: The bacteria in our guts can make us fat.
# False answer: The more bacteria there are in our guts, the fatter we will be.
# ...
# 812  False answer: Food
# False answer: Water
# False answer: Sleep
# 813  False answer: 73 days old
# False answer: 73 months old
# False answer: 73 weeks old
# 814  False answer: A shirt
# False answer: Some books
# False answer: A fruit
# 815  False answer: It's twenty-nine yuan
# False answer: It's thirty dollars
# False answer: It's thirty-nine yuan
# 816  False answer: Aug.6th.
# False answer: Aug.4th.
# False answer: Aug.8th.
# 817  False answer: The name of her present is in it.
# False answer: Her present is in a red box.
# False answer: Her present is on the chair.
# 818  False answer: In her bag.
# False answer: In her bedroom.
# False answer: In her box.
# 819  False answer: A book.
# False answer: A bag.
# False answer: A computer.
# 820  False answer: they went too far away
# False answer: they didn't know the way
# False answer: it was a winter evening
# 821  False answer: Annoyed.
# False answer: Angry.
# False answer: Excited.
# 822  False answer: Her family doesn't have enough food.
# False answer: Her mother can't do anything at home.
# False answer: She has no brothers or sisters.
# 823  False answer: A place where children can get food.
# False answer: A group who works for children in rich places.
# False answer: A place where children can get education.
# 824  False answer: Project Hope
# False answer: Save the Children
# False answer: Save the Children
# 825  False answer: 150,000
# False answer: 200
# False answer: more than 300,000
# 826  False answer: About shoes.
# False answer: About time.
# False answer: About hair.
# 827  False answer: The students are not allowed to wear earrings.
# False answer: The students must wear sports shoes in PE class.
# False answer: The students are not allowed to have part-time jobs.
# 828  False answer: He helped clear flyers from telephone poles.
# False answer: He did some community work in Shanghai.
# False answer: He helped his classmates with their school work.
# 829  False answer: Go to the factory.
# False answer: Buy a book.
# False answer: Try it yourself
# 830  False answer: Because they have to go to school the next day.
# False answer: Because they are tired
# False answer: Because they don't like to stay at the park any more.
# 831  False answer: Her dad.
# False answer: Her brother.
# False answer: Her grandma.
# 832  False answer: She is a woman.
# False answer: She is busy.
# False answer: She doesn't like to do housework.
# 833  False answer: They pay for children's rides to the sea.
# False answer: They pay for children's lunch at the seaside.
# False answer: They give children money to go home by taxi.
# 834  False answer: they want to make the foods smell better
# False answer: they want to make the foods cheaper
# False answer: they want to make the foods taste better and last longer
# 835  False answer: Catherine
# False answer: Linda
# False answer: We don't know.
# 836  False answer: Her mother's family.
# False answer: Her cousin's family.
# False answer: Her aunt's family.
# 837  False answer: An ice skates.
# False answer: A dollhouse.
# False answer: Red leather gloves.
# 838  False answer: Bill
# False answer: Dave
# False answer: All of them
# 839  False answer: Because he wanted to eat them.
# False answer: Because he didn't like them.
# False answer: Because his mother asked him to do so.
# 840  False answer: His mother.
# False answer: His sister.
# False answer: His father.
# 841  False answer: teacher
# False answer: writer
# False answer: editor
# 842  False answer: Tears of a Tiger is a New York Times Bestseller.
# False answer: She has received many awards for her books.
# False answer: She has been honored as the National Teacher of the Year.
# 843  False answer: About 2.67 million square kilometers.
# False answer: 121.8 million hectares.
# False answer: About 121.8 million hectares.
# 844  False answer: Beijing.
# False answer: Shanghai.
# False answer: Dalian.
# 845  False answer: Class 2 , Grade 6.
# False answer: Class 2 , Grade 5.
# False answer: Class 2 , Grade 4.
# 846  False answer: 12.
# False answer: 13.
# False answer: 14.
# 847  False answer: It was a quiet town.
# False answer: It was a museum.
# False answer: It was a hotel.
# 848  False answer: Some teachers.
# False answer: Some friends.
# False answer: Some tourists.
# 849  False answer: Expensive.
# False answer: Tired.
# False answer: Boring.
# 850  False answer: Rita was fond of dolls when she was a little girl
# False answer: Rita's parents always gave her a doll on her birthdays
# False answer: Rita's parents reminded her of her mother's death
# 851  False answer: Because money is not important to us.
# False answer: Because money can't buy people's happiness.
# False answer: Because money can bring people happiness.
# 852  False answer: Happy School.
# False answer: Happy Factory.
# False answer: Happy Home.
# 853  False answer: In a real garden.
# False answer: In a school of the Internet.
# False answer: At home.
# 854  False answer: Some people have great fun fighting others' vegetables.
# False answer: Some people need to water, sell and steal vegetables, flowers, fruits and so on.
# False answer: Some people can earn some e-money from their working on the farm.
# 855  False answer: Because students have great fun fighting with others.
# False answer: Because students don't study at home.
# False answer: Because students don't have enough money.
# 856  False answer: Because the customer wanted to hear him play the piano.
# False answer: Because the customer was a big fan of his.
# False answer: Because the customer wanted to make money.
# 857  False answer: For he was good at it.
# False answer: For he liked to do it.
# False answer: For he was a musician.
# 858  False answer: Because he was a good piano player.
# False answer: Because he worked hard.
# False answer: Because he wanted to be an entertainer.
# 859  False answer: 9
# False answer: 17
# False answer: 74
# 860  False answer: Two.
# False answer: Four.
# False answer: Five.
# 861  False answer: In bookshops.
# False answer: On the Internet.
# False answer: In bookstores.
# 862  False answer: the China Pavilion.
# False answer: the Oil Pavilion.
# False answer: the 4-D films Pavilion.
# 863  False answer: For about 10 days.
# False answer: For about 30 days.
# False answer: For about 40 days.
# 864  False answer: 16.
# False answer: 80.
# False answer: 16.
# 865  False answer: the ways tigers treat their young
# False answer: the physical training of soldiers
# False answer: the mental training of teachers
# 866  False answer: concentrate on children's physical conditions
# False answer: push children off cliffs
# False answer: teach children how to fly
# 867  False answer: In January
# False answer: In February
# False answer: In March
# 868  False answer: He considered himself a superstar.
# False answer: He would like to give back to society by taking advantage of his fame.
# False answer: He would like to do well in society anonymously.
# 869  False answer: He is a Chinese writer.
# False answer: He is an established Australian writer.
# False answer: He is an ordinary reader of the works.
# 870  False answer: Ten.
# False answer: Five.
# False answer: Twenty-three.
# 871  False answer: A good design.
# False answer: A fast car.
# False answer: Some skills.
# 872  False answer: 19 seconds.
# False answer: 74.8 seconds.
# False answer: 20.1 seconds.
# 873  False answer: They like to eat good food.
# False answer: They like to play in the streets.
# False answer: They like to live in old houses.
# 874  False answer: They can be taught to talk.
# False answer: They can be taught to read.
# False answer: They can be taught to write.
# 875  False answer: It is a good way of learning the freshest news.
# False answer: It is easy and fast to write.
# False answer: It can talk with friends.
# 876  False answer: Could you give me five minutes?
# False answer: I'm afraid I can't
# False answer: Would you mind...?
# 877  False answer: Would you mind not using your phone in the cinema?
# False answer: Would you mind not talking on your phone in the cinema?
# False answer: Would you mind stopping your car here?
# 878  False answer: Once a week.
# False answer: Twice or three times a day.
# False answer: Every day.
# 879  False answer: Six.
# False answer: Ten.
# False answer: Twelve.
# 880  False answer: Because her parents are always happy with her.
# False answer: Because her friends don't like her parents.
# False answer: Because her parents don't care about her school grades.
# 881  False answer: Don't mind what her parents think.
# False answer: Don't go out as late as her friends.
# False answer: Don't listen to any noise.
# 882  False answer: His clean and youthful image.
# False answer: His acting skills.
# False answer: His personal behavior.
# 883  False answer: 3 minutes
# False answer: 14 minutes
# False answer: 23 minutes
# 884  False answer: He thinks Ko is very talented.
# False answer: He doesn't care about Ko's behavior.
# False answer: He supports what Ko did.
# 885  False answer: Black.
# False answer: White.
# False answer: Green.
# 886  False answer: Water.
# False answer: Coke.
# False answer: Orange juice.
# 887  False answer: It will waste energy.
# False answer: It will take a long time to warm up.
# False answer: It will help to make the room warm.
# 888  False answer: Ways 1 & 2.
# False answer: Way 5.
# False answer: Ways 2 & 3.
# 889  False answer: They all help to save money.
# False answer: They all help to save wood.
# False answer: They all produce more clean air.
# 890  False answer: Making cleaner air.
# False answer: Saving the environment.
# False answer: Getting a second, third, or tenth use out of them.
# 891  False answer: Because children in smaller groups are more active.
# False answer: Because children in smaller groups eat more food.
# False answer: Because children in smaller groups have more fun.
# 892  False answer: The problems of making bread.
# False answer: The problems of getting old.
# False answer: The problems of making bread.
# 893  False answer: They are getting old.
# False answer: They are too old to work.
# False answer: They can't find jobs.
# 894  False answer: The first woman.
# False answer: The second woman.
# False answer: The last woman.
# 895  False answer: Half an hour.
# False answer: Two hours.
# False answer: More than two hours.
# 896  False answer: The angry man.
# False answer: The writer.
# False answer: The writer's wife.
# 897  False answer: Chicken.
# False answer: Fish.
# False answer: Meat.
# 898  False answer: We must eat more vegetables and fruit.
# False answer: We must do enough sport every day.
# False answer: We must watch TV and read in right ways.
# 899  False answer: Someone is calling me
# False answer: You must stay in one place
# False answer: It is night and you must find a room
# 900  False answer: Make a small room with branches.
# False answer: Stay in one place.
# False answer: Whistle or shout for help.
# 901  False answer: 300.
# False answer: 1.
# False answer: 2.
# 902  False answer: He dropped the bill on the floor.
# False answer: He stepped on the bill.
# False answer: He asked the students to put up their hands.
# 903  False answer: A lot.
# False answer: Many.
# False answer: 25,000.
# 904  False answer: He sent some firefighters to fight the fire.
# False answer: He sent money to the Red Cross.
# False answer: He gave all of his beer to the people in Fort McMurray.
# 905  False answer: They could play with all the toys at once.
# False answer: They could choose the toys they liked.
# False answer: They could play with toys they made by themselves.
# 906  False answer: Four.
# False answer: Five.
# False answer: Seven.
# 907  False answer: She had no chance to work.
# False answer: She didn't get along well with her friends.
# False answer: She didn't get a high score in the GRE.
# 908  False answer: Bored.
# False answer: Lost.
# False answer: Frightened.
# 909  False answer: They want to keep warm.
# False answer: They want to have fun.
# False answer: They want to eat more food.
# 910  False answer: She is afraid of hurting her friends.
# False answer: She does not understand true friendship.
# False answer: She does not put her needs first.
# 911  False answer: in California
# False answer: in McDonal's
# False answer: in a poor village in Mexico
# 912  False answer: Some pictures
# False answer: Some flowers
# False answer: Some medicine
# 913  False answer: He kept it for himself.
# False answer: He gave it to the police.
# False answer: He gave it to his boss.
# 914  False answer: Because the old house was too small.
# False answer: Because the family had never had a new house.
# False answer: Because the group was too busy to repair the old house.
# 915  False answer: Australia.
# False answer: Africa.
# False answer: Canada.
# 916  False answer: Green, yellow and white.
# False answer: Red, orange and green.
# False answer: White, blue and purple.
# 917  False answer: Thirteen
# False answer: Fourteen
# False answer: Fifteen
# 918  False answer: Shanghai
# False answer: Nanjing
# False answer: London
# 919  False answer: Amy
# False answer: Millie
# False answer: Nobody
# 920  False answer: A teacher.
# False answer: A worker.
# False answer: A manager.
# 921  False answer: Tall.
# False answer: Strong.
# False answer: Slim and tall.
# 922  False answer: A teacher.
# False answer: A worker.
# False answer: A nurse.
# 923  False answer: Blue.
# False answer: Black.
# False answer: Red.
# 924  False answer: Money.
# False answer: Friendship.
# False answer: Health.
# 925  False answer: Because it makes the earth bright.
# False answer: Because we can see it every day.
# False answer: Because it is the nearest of all stars.
# 926  False answer: Because they were afraid to leave.
# False answer: Because the teacher told them to stay in their class.
# False answer: Because they didn't have anything to do.
# 927  False answer: Working in the kid's house.
# False answer: Telling English stories to the kid.
# False answer: Working in the kid's free time.
# 928  False answer: have three years' experience
# False answer: work on Saturdays and Sundays
# False answer: have good at English
# 929  False answer: Once
# False answer: Three times
# False answer: Many times
# 930  False answer: The scientists from the Lockheed Space Company work in Felton.
# False answer: The computer was placed in Felton.
# False answer: The designs were copies after a time.
# 931  False answer: Because their parents don't want them.
# False answer: Because they don't want to leave their grandparents.
# False answer: Because their parents can't afford to leave them.
# 932  False answer: Money and games.
# False answer: Food and money.
# False answer: Love and money.
# 933  False answer: His parents' death.
# False answer: His dog Tiger.
# False answer: The young lady.
# 934  False answer: In 1961.
# False answer: In 1955.
# False answer: In 1913.
# 935  False answer: In Kansas.
# False answer: In Hawaii and Kansas.
# False answer: In Gaomi.
# 936  False answer: When the moon appears very blue.
# False answer: When there is only one full moon in one month.
# False answer: When a crescent moon can be seen.
# 937  False answer: More than once a year.
# False answer: Once a month.
# False answer: Twice a month.
# 938  False answer: a waiter
# False answer: a driver
# False answer: a cleaner
# 939  False answer: Is this the door?
# False answer: What's the time,please?
# False answer: Where is the club?
# 940  False answer: Yes, he did
# False answer: Yes, he didn't
# False answer: No, he did
# 941  False answer: The temperature is usually normal.
# False answer: People can make their living by catching fish.
# False answer: The resources like oil can bring them much money.
# 942  False answer: Try our best to finish what we have to do .
# False answer: Draw a useful lesson from it and try our best to finish what we have to do .
# False answer: With an optimistic attitude , life is easy and pleasant .
# 943  False answer: A Chinese class
# False answer: An English class
# False answer: A cooking class
# 944  False answer: Chinese
# False answer: Japanese
# False answer: French
# 945  False answer: Chinese
# False answer: English
# False answer: Japanese
# 946  False answer: In Chinese
# False answer: In Japanese
# False answer: In French
# 947  False answer: The food
# False answer: The language
# False answer: The people
# 948  False answer: They are watching a movie.
# False answer: They are playing football.
# False answer: They are doing some shopping.
# 949  False answer: They might go to a cinema.
# False answer: They might go to a library.
# False answer: They might go to a park.

# %%
with open(outfile, 'w') as f:
    json.dump(generated, f)
